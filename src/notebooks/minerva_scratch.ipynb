# %%
# !ls
# Out:
# gdelt_gkg_themes_frequency.csv
# GDELT-Global_Knowledge_Graph_CategoryList.xlsx
# Getting Started with GDELT + Google Cloud Datalab - Simple Timelines.ipynb
# google-cloud-sdk
# google-cloud-sdk-179.0.0-linux-x86_64.tar.gz
# minerva_scratch.ipynb

# %%
import pandas as pd

# %%
df = pd.read_csv('gdelt_gkg_themes_frequency.csv')

# %%
df.count()
# Out:
# theme    53541
# count    53542
# dtype: int64

# %%
df.head(3000)
# Out:
#                                                   theme      count
# 0                               USPEC_POLITICS_GENERAL1  347091920
# 1                                  CRISISLEX_C07_SAFETY  345375313
# 2                                                LEADER  340884497
# 3                                CRISISLEX_CRISISLEXREC  318723554
# 4                                    GENERAL_GOVERNMENT  314932858
# 5                                             EDUCATION  292911270
# 6                              MANMADE_DISASTER_IMPLIED  280289912
# 7                                        GENERAL_HEALTH  258623663
# 8                                     SECURITY_SERVICES  253139772
# 9                                         USPEC_POLICY1  250380136
# 10                                    TAX_FNCACT_POLICE  245861476
# 11                      WB_696_PUBLIC_SECTOR_MANAGEMENT  238289475
# 12                                              MEDICAL  237724761
# ...

# %%
df.query('count >= 1000')
# Out:
#                                                    theme      count
# 0                                USPEC_POLITICS_GENERAL1  347091920
# 1                                   CRISISLEX_C07_SAFETY  345375313
# 2                                                 LEADER  340884497
# 3                                 CRISISLEX_CRISISLEXREC  318723554
# 4                                     GENERAL_GOVERNMENT  314932858
# 5                                              EDUCATION  292911270
# 6                               MANMADE_DISASTER_IMPLIED  280289912
# 7                                         GENERAL_HEALTH  258623663
# 8                                      SECURITY_SERVICES  253139772
# 9                                          USPEC_POLICY1  250380136
# 10                                     TAX_FNCACT_POLICE  245861476
# 11                       WB_696_PUBLIC_SECTOR_MANAGEMENT  238289475
# 12                                               MEDICAL  237724761
# ...
